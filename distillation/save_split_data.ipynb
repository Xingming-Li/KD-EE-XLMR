# %%
import os
import math
import pandas as pd
from datasets import load_dataset, Dataset
from transformers import XLMRobertaTokenizer
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')

# Define path in Google Drive
# Minimal distillation data are saved for a quick access.
DATA_DIR = "/content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data"
TXT_DIR = "/content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_txt"
os.makedirs(DATA_DIR, exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Define languages
languages = {'af': 1.3, 'am': 0.8, 'ar': 28.0, 'as': 0.1, 'az': 6.5,
       'be': 4.3, 'bg': 57.5, 'bn': 8.4, 'bn_rom': 0.5, 'br': 0.1,
       'bs': 0.1, 'ca': 10.1, 'cs': 16.3, 'cy': 0.8, 'da': 45.6,
       'de': 66.6, 'el': 46.9, 'en': 300.8, 'eo': 0.9, 'es': 53.3,
       'et': 6.1, 'eu': 2.0, 'fa': 111.6, 'fi': 54.3, 'fr': 56.8,
       'fy': 0.2, 'ga': 0.5, 'gd': 0.1, 'gl': 2.9, 'gu': 1.9, 'ha': 0.3,
       'he': 31.6, 'hi': 20.2, 'hi_rom': 0.5, 'hr': 20.5, 'hu': 58.4,
       'hy': 5.5, 'id': 148.3, 'is': 3.2, 'it': 30.2, 'ja': 69.3,
       'jv': 0.2, 'ka': 9.1, 'kk': 6.4, 'km': 1.5, 'kn': 3.3, 'ko': 54.2,
       'ku': 0.4, 'ky': 1.2, 'la': 2.5, 'lo': 0.6, 'lt': 13.7, 'lv': 8.8,
       'mg': 0.2, 'mk': 4.8, 'ml': 7.6, 'mn': 3.0, 'mr': 2.8, 'ms': 8.5,
       'my': 0.4, 'my_zaw': 1.6, 'ne': 3.8, 'nl': 29.3, 'no': 49.0,
       'om': 0.1, 'or': 0.6, 'pa': 0.8, 'pl': 44.6, 'ps': 0.7,
       'pt': 49.1, 'ro': 61.4, 'ru': 278.0, 'sa': 0.3, 'sd': 0.4,
       'si': 3.6, 'sk': 23.2, 'sl': 10.3, 'so': 0.4, 'sq': 5.4,
       'sr': 9.1, 'su': 0.1, 'sv': 12.1, 'sw': 1.6, 'ta': 12.2,
       'ta_rom': 0.3, 'te': 4.7, 'te_rom': 0.3, 'th': 71.7, 'tl': 3.1,
       'tr': 20.9, 'ug': 0.4, 'uk': 84.6, 'ur': 5.7, 'ur_rom': 0.5,
       'uz': 0.7, 'vi': 137.3, 'xh': 0.1, 'yi': 0.3, 'zh-Hans': 46.9,
       'zh-Hant': 16.6
}

# %%
# Initialize tokenizer
tokenizer = XLMRobertaTokenizer.from_pretrained("xlm-roberta-large")

def preprocess_and_save(lang):
    print(f"Processing {lang}...")
    txt_path = os.path.join(TXT_DIR, f"{lang}.txt")

    # Read lines into Hugging Face Dataset
    with open(txt_path, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f if line.strip()]
    dataset = Dataset.from_dict({"text": lines})

    def tokenize_function(examples):
        return tokenizer(
            examples["text"],
            padding="max_length",
            truncation=True,
            max_length=256
        )

    tokenized = dataset.map(tokenize_function, batched=True, batch_size=1000)

    # Save as compressed Parquet
    save_path = os.path.join(DATA_DIR, f"{lang}.parquet")
    tokenized.to_parquet(save_path)
    print(f"Saved {lang} dataset at {save_path}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
for lang in languages:
    save_path = os.path.join(DATA_DIR, f"{lang}.parquet")
    if not os.path.exists(save_path):
        preprocess_and_save(lang)
    else:
        print(f"{lang} dataset already exists in Google Drive.")
# Out:
# Processing af...
# Map:   0%|          | 0/13 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved af dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/af.parquet
# Processing am...
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved am dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/am.parquet
# Processing ar...
# Map:   0%|          | 0/280 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ar dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ar.parquet
# Processing as...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved as dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/as.parquet
# Processing az...
# Map:   0%|          | 0/65 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved az dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/az.parquet
# Processing be...
# Map:   0%|          | 0/43 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved be dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/be.parquet
# Processing bg...
# Map:   0%|          | 0/575 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved bg dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/bg.parquet
# Processing bn...
# Map:   0%|          | 0/84 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved bn dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/bn.parquet
# Processing bn_rom...
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved bn_rom dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/bn_rom.parquet
# Processing br...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved br dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/br.parquet
# Processing bs...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved bs dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/bs.parquet
# Processing ca...
# Map:   0%|          | 0/101 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ca dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ca.parquet
# Processing cs...
# Map:   0%|          | 0/163 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved cs dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/cs.parquet
# Processing cy...
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved cy dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/cy.parquet
# Processing da...
# Map:   0%|          | 0/456 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved da dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/da.parquet
# Processing de...
# Map:   0%|          | 0/666 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved de dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/de.parquet
# Processing el...
# Map:   0%|          | 0/469 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved el dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/el.parquet
# Processing en...
# Map:   0%|          | 0/3008 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/4 [00:00<?, ?ba/s]
# Saved en dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/en.parquet
# Processing eo...
# Map:   0%|          | 0/9 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved eo dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/eo.parquet
# Processing es...
# Map:   0%|          | 0/533 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved es dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/es.parquet
# Processing et...
# Map:   0%|          | 0/61 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved et dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/et.parquet
# Processing eu...
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved eu dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/eu.parquet
# Processing fa...
# Map:   0%|          | 0/1116 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Saved fa dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/fa.parquet
# Processing fi...
# Map:   0%|          | 0/543 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved fi dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/fi.parquet
# Processing fr...
# Map:   0%|          | 0/568 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved fr dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/fr.parquet
# Processing fy...
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved fy dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/fy.parquet
# Processing ga...
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ga dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ga.parquet
# Processing gd...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved gd dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/gd.parquet
# Processing gl...
# Map:   0%|          | 0/29 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved gl dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/gl.parquet
# Processing gu...
# Map:   0%|          | 0/19 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved gu dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/gu.parquet
# Processing ha...
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ha dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ha.parquet
# Processing he...
# Map:   0%|          | 0/316 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved he dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/he.parquet
# Processing hi...
# Map:   0%|          | 0/202 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved hi dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/hi.parquet
# Processing hi_rom...
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved hi_rom dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/hi_rom.parquet
# Processing hr...
# Map:   0%|          | 0/205 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved hr dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/hr.parquet
# Processing hu...
# Map:   0%|          | 0/584 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved hu dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/hu.parquet
# Processing hy...
# Map:   0%|          | 0/55 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved hy dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/hy.parquet
# Processing id...
# Map:   0%|          | 0/1483 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Saved id dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/id.parquet
# Processing is...
# Map:   0%|          | 0/32 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved is dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/is.parquet
# Processing it...
# Map:   0%|          | 0/302 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved it dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/it.parquet
# Processing ja...
# Map:   0%|          | 0/693 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ja dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ja.parquet
# Processing jv...
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved jv dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/jv.parquet
# Processing ka...
# Map:   0%|          | 0/91 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ka dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ka.parquet
# Processing kk...
# Map:   0%|          | 0/64 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved kk dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/kk.parquet
# Processing km...
# Map:   0%|          | 0/15 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved km dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/km.parquet
# Processing kn...
# Map:   0%|          | 0/33 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved kn dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/kn.parquet
# Processing ko...
# Map:   0%|          | 0/542 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ko dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ko.parquet
# Processing ku...
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ku dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ku.parquet
# Processing ky...
# Map:   0%|          | 0/12 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ky dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ky.parquet
# Processing la...
# Map:   0%|          | 0/25 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved la dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/la.parquet
# Processing lo...
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved lo dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/lo.parquet
# Processing lt...
# Map:   0%|          | 0/137 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved lt dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/lt.parquet
# Processing lv...
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved lv dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/lv.parquet
# Processing mg...
# Map:   0%|          | 0/2 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved mg dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/mg.parquet
# Processing mk...
# Map:   0%|          | 0/48 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved mk dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/mk.parquet
# Processing ml...
# Map:   0%|          | 0/76 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ml dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ml.parquet
# Processing mn...
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved mn dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/mn.parquet
# Processing mr...
# Map:   0%|          | 0/28 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved mr dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/mr.parquet
# Processing ms...
# Map:   0%|          | 0/85 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ms dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ms.parquet
# Processing my...
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved my dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/my.parquet
# Processing my_zaw...
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved my_zaw dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/my_zaw.parquet
# Processing ne...
# Map:   0%|          | 0/38 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ne dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ne.parquet
# Processing nl...
# Map:   0%|          | 0/293 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved nl dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/nl.parquet
# Processing no...
# Map:   0%|          | 0/490 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved no dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/no.parquet
# Processing om...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved om dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/om.parquet
# Processing or...
# Map:   0%|          | 0/6 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved or dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/or.parquet
# Processing pa...
# Map:   0%|          | 0/8 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved pa dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/pa.parquet
# Processing pl...
# Map:   0%|          | 0/446 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved pl dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/pl.parquet
# Processing ps...
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ps dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ps.parquet
# Processing pt...
# Map:   0%|          | 0/491 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved pt dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/pt.parquet
# Processing ro...
# Map:   0%|          | 0/614 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ro dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ro.parquet
# Processing ru...
# Map:   0%|          | 0/2780 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/3 [00:00<?, ?ba/s]
# Saved ru dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ru.parquet
# Processing sa...
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sa dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sa.parquet
# Processing sd...
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sd dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sd.parquet
# Processing si...
# Map:   0%|          | 0/36 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved si dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/si.parquet
# Processing sk...
# Map:   0%|          | 0/232 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sk dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sk.parquet
# Processing sl...
# Map:   0%|          | 0/103 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sl dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sl.parquet
# Processing so...
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved so dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/so.parquet
# Processing sq...
# Map:   0%|          | 0/54 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sq dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sq.parquet
# Processing sr...
# Map:   0%|          | 0/91 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sr dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sr.parquet
# Processing su...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved su dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/su.parquet
# Processing sv...
# Map:   0%|          | 0/121 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sv dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sv.parquet
# Processing sw...
# Map:   0%|          | 0/16 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved sw dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/sw.parquet
# Processing ta...
# Map:   0%|          | 0/122 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ta dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ta.parquet
# Processing ta_rom...
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ta_rom dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ta_rom.parquet
# Processing te...
# Map:   0%|          | 0/47 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved te dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/te.parquet
# Processing te_rom...
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved te_rom dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/te_rom.parquet
# Processing th...
# Map:   0%|          | 0/717 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved th dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/th.parquet
# Processing tl...
# Map:   0%|          | 0/31 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved tl dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/tl.parquet
# Processing tr...
# Map:   0%|          | 0/209 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved tr dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/tr.parquet
# Processing ug...
# Map:   0%|          | 0/4 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ug dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ug.parquet
# Processing uk...
# Map:   0%|          | 0/846 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved uk dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/uk.parquet
# Processing ur...
# Map:   0%|          | 0/57 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ur dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ur.parquet
# Processing ur_rom...
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved ur_rom dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/ur_rom.parquet
# Processing uz...
# Map:   0%|          | 0/7 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved uz dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/uz.parquet
# Processing vi...
# Map:   0%|          | 0/1373 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/2 [00:00<?, ?ba/s]
# Saved vi dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/vi.parquet
# Processing xh...
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved xh dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/xh.parquet
# Processing yi...
# Map:   0%|          | 0/3 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved yi dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/yi.parquet
# Processing zh-Hans...
# Map:   0%|          | 0/469 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved zh-Hans dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/zh-Hans.parquet
# Processing zh-Hant...
# Map:   0%|          | 0/166 [00:00<?, ? examples/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# Saved zh-Hant dataset at /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data/zh-Hant.parquet

# %%
def split_parquet_into_n_chunks(parquet_path, out_dir, lang_code, num_chunks=5):
    df = pd.read_parquet(parquet_path)
    total_rows = len(df)
    rows_per_chunk = math.ceil(total_rows / num_chunks)

    os.makedirs(out_dir, exist_ok=True)

    for i in range(num_chunks):
        start_idx = i * rows_per_chunk
        end_idx = min(start_idx + rows_per_chunk, total_rows)
        chunk = df.iloc[start_idx:end_idx]

        out_path = os.path.join(out_dir, f"{lang_code}_{i}.parquet")
        chunk.to_parquet(out_path, index=False)
        print(f"Saved {lang_code} chunk {i} with {len(chunk)} rows to {out_path}")

# %%
OUTPUT_DIR = "/content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split"
os.makedirs(OUTPUT_DIR, exist_ok=True)

for lang in languages:
    split_parquet_into_n_chunks(
        f"{DATA_DIR}/{lang}.parquet",
        OUTPUT_DIR,
        lang,
        num_chunks=5
    )
# Out:
# Saved af chunk 0 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/af_0.parquet
# Saved af chunk 1 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/af_1.parquet
# Saved af chunk 2 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/af_2.parquet
# Saved af chunk 3 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/af_3.parquet
# Saved af chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/af_4.parquet
# Saved am chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/am_0.parquet
# Saved am chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/am_1.parquet
# Saved am chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/am_2.parquet
# Saved am chunk 3 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/am_3.parquet
# Saved am chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/am_4.parquet
# Saved ar chunk 0 with 56 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ar_0.parquet
# Saved ar chunk 1 with 56 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ar_1.parquet
# Saved ar chunk 2 with 56 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ar_2.parquet
# Saved ar chunk 3 with 56 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ar_3.parquet
# Saved ar chunk 4 with 56 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ar_4.parquet
# Saved as chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/as_0.parquet
# Saved as chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/as_1.parquet
# Saved as chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/as_2.parquet
# Saved as chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/as_3.parquet
# Saved as chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/as_4.parquet
# Saved az chunk 0 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/az_0.parquet
# Saved az chunk 1 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/az_1.parquet
# Saved az chunk 2 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/az_2.parquet
# Saved az chunk 3 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/az_3.parquet
# Saved az chunk 4 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/az_4.parquet
# Saved be chunk 0 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/be_0.parquet
# Saved be chunk 1 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/be_1.parquet
# Saved be chunk 2 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/be_2.parquet
# Saved be chunk 3 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/be_3.parquet
# Saved be chunk 4 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/be_4.parquet
# Saved bg chunk 0 with 115 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bg_0.parquet
# Saved bg chunk 1 with 115 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bg_1.parquet
# Saved bg chunk 2 with 115 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bg_2.parquet
# Saved bg chunk 3 with 115 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bg_3.parquet
# Saved bg chunk 4 with 115 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bg_4.parquet
# Saved bn chunk 0 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_0.parquet
# Saved bn chunk 1 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_1.parquet
# Saved bn chunk 2 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_2.parquet
# Saved bn chunk 3 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_3.parquet
# Saved bn chunk 4 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_4.parquet
# Saved bn_rom chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_rom_0.parquet
# Saved bn_rom chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_rom_1.parquet
# Saved bn_rom chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_rom_2.parquet
# Saved bn_rom chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_rom_3.parquet
# Saved bn_rom chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bn_rom_4.parquet
# Saved br chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/br_0.parquet
# Saved br chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/br_1.parquet
# Saved br chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/br_2.parquet
# Saved br chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/br_3.parquet
# Saved br chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/br_4.parquet
# Saved bs chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bs_0.parquet
# Saved bs chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bs_1.parquet
# Saved bs chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bs_2.parquet
# Saved bs chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bs_3.parquet
# Saved bs chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/bs_4.parquet
# Saved ca chunk 0 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ca_0.parquet
# Saved ca chunk 1 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ca_1.parquet
# Saved ca chunk 2 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ca_2.parquet
# Saved ca chunk 3 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ca_3.parquet
# Saved ca chunk 4 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ca_4.parquet
# Saved cs chunk 0 with 33 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cs_0.parquet
# Saved cs chunk 1 with 33 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cs_1.parquet
# Saved cs chunk 2 with 33 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cs_2.parquet
# Saved cs chunk 3 with 33 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cs_3.parquet
# Saved cs chunk 4 with 31 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cs_4.parquet
# Saved cy chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cy_0.parquet
# Saved cy chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cy_1.parquet
# Saved cy chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cy_2.parquet
# Saved cy chunk 3 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cy_3.parquet
# Saved cy chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/cy_4.parquet
# Saved da chunk 0 with 92 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/da_0.parquet
# Saved da chunk 1 with 92 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/da_1.parquet
# Saved da chunk 2 with 92 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/da_2.parquet
# Saved da chunk 3 with 92 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/da_3.parquet
# Saved da chunk 4 with 88 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/da_4.parquet
# Saved de chunk 0 with 134 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/de_0.parquet
# Saved de chunk 1 with 134 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/de_1.parquet
# Saved de chunk 2 with 134 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/de_2.parquet
# Saved de chunk 3 with 134 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/de_3.parquet
# Saved de chunk 4 with 130 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/de_4.parquet
# Saved el chunk 0 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/el_0.parquet
# Saved el chunk 1 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/el_1.parquet
# Saved el chunk 2 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/el_2.parquet
# Saved el chunk 3 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/el_3.parquet
# Saved el chunk 4 with 93 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/el_4.parquet
# Saved en chunk 0 with 602 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/en_0.parquet
# Saved en chunk 1 with 602 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/en_1.parquet
# Saved en chunk 2 with 602 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/en_2.parquet
# Saved en chunk 3 with 602 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/en_3.parquet
# Saved en chunk 4 with 600 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/en_4.parquet
# Saved eo chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eo_0.parquet
# Saved eo chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eo_1.parquet
# Saved eo chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eo_2.parquet
# Saved eo chunk 3 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eo_3.parquet
# Saved eo chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eo_4.parquet
# Saved es chunk 0 with 107 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/es_0.parquet
# Saved es chunk 1 with 107 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/es_1.parquet
# Saved es chunk 2 with 107 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/es_2.parquet
# Saved es chunk 3 with 107 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/es_3.parquet
# Saved es chunk 4 with 105 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/es_4.parquet
# Saved et chunk 0 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/et_0.parquet
# Saved et chunk 1 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/et_1.parquet
# Saved et chunk 2 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/et_2.parquet
# Saved et chunk 3 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/et_3.parquet
# Saved et chunk 4 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/et_4.parquet
# Saved eu chunk 0 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eu_0.parquet
# Saved eu chunk 1 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eu_1.parquet
# Saved eu chunk 2 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eu_2.parquet
# Saved eu chunk 3 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eu_3.parquet
# Saved eu chunk 4 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/eu_4.parquet
# Saved fa chunk 0 with 224 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fa_0.parquet
# Saved fa chunk 1 with 224 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fa_1.parquet
# Saved fa chunk 2 with 224 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fa_2.parquet
# Saved fa chunk 3 with 224 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fa_3.parquet
# Saved fa chunk 4 with 220 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fa_4.parquet
# Saved fi chunk 0 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fi_0.parquet
# Saved fi chunk 1 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fi_1.parquet
# Saved fi chunk 2 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fi_2.parquet
# Saved fi chunk 3 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fi_3.parquet
# Saved fi chunk 4 with 107 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fi_4.parquet
# Saved fr chunk 0 with 114 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fr_0.parquet
# Saved fr chunk 1 with 114 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fr_1.parquet
# Saved fr chunk 2 with 114 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fr_2.parquet
# Saved fr chunk 3 with 114 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fr_3.parquet
# Saved fr chunk 4 with 112 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fr_4.parquet
# Saved fy chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fy_0.parquet
# Saved fy chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fy_1.parquet
# Saved fy chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fy_2.parquet
# Saved fy chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fy_3.parquet
# Saved fy chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/fy_4.parquet
# Saved ga chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ga_0.parquet
# Saved ga chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ga_1.parquet
# Saved ga chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ga_2.parquet
# Saved ga chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ga_3.parquet
# Saved ga chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ga_4.parquet
# Saved gd chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gd_0.parquet
# Saved gd chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gd_1.parquet
# Saved gd chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gd_2.parquet
# Saved gd chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gd_3.parquet
# Saved gd chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gd_4.parquet
# Saved gl chunk 0 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gl_0.parquet
# Saved gl chunk 1 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gl_1.parquet
# Saved gl chunk 2 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gl_2.parquet
# Saved gl chunk 3 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gl_3.parquet
# Saved gl chunk 4 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gl_4.parquet
# Saved gu chunk 0 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gu_0.parquet
# Saved gu chunk 1 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gu_1.parquet
# Saved gu chunk 2 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gu_2.parquet
# Saved gu chunk 3 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gu_3.parquet
# Saved gu chunk 4 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/gu_4.parquet
# Saved ha chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ha_0.parquet
# Saved ha chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ha_1.parquet
# Saved ha chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ha_2.parquet
# Saved ha chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ha_3.parquet
# Saved ha chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ha_4.parquet
# Saved he chunk 0 with 64 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/he_0.parquet
# Saved he chunk 1 with 64 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/he_1.parquet
# Saved he chunk 2 with 64 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/he_2.parquet
# Saved he chunk 3 with 64 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/he_3.parquet
# Saved he chunk 4 with 60 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/he_4.parquet
# Saved hi chunk 0 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_0.parquet
# Saved hi chunk 1 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_1.parquet
# Saved hi chunk 2 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_2.parquet
# Saved hi chunk 3 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_3.parquet
# Saved hi chunk 4 with 38 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_4.parquet
# Saved hi_rom chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_rom_0.parquet
# Saved hi_rom chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_rom_1.parquet
# Saved hi_rom chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_rom_2.parquet
# Saved hi_rom chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_rom_3.parquet
# Saved hi_rom chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hi_rom_4.parquet
# Saved hr chunk 0 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hr_0.parquet
# Saved hr chunk 1 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hr_1.parquet
# Saved hr chunk 2 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hr_2.parquet
# Saved hr chunk 3 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hr_3.parquet
# Saved hr chunk 4 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hr_4.parquet
# Saved hu chunk 0 with 117 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hu_0.parquet
# Saved hu chunk 1 with 117 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hu_1.parquet
# Saved hu chunk 2 with 117 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hu_2.parquet
# Saved hu chunk 3 with 117 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hu_3.parquet
# Saved hu chunk 4 with 116 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hu_4.parquet
# Saved hy chunk 0 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hy_0.parquet
# Saved hy chunk 1 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hy_1.parquet
# Saved hy chunk 2 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hy_2.parquet
# Saved hy chunk 3 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hy_3.parquet
# Saved hy chunk 4 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/hy_4.parquet
# Saved id chunk 0 with 297 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/id_0.parquet
# Saved id chunk 1 with 297 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/id_1.parquet
# Saved id chunk 2 with 297 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/id_2.parquet
# Saved id chunk 3 with 297 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/id_3.parquet
# Saved id chunk 4 with 295 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/id_4.parquet
# Saved is chunk 0 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/is_0.parquet
# Saved is chunk 1 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/is_1.parquet
# Saved is chunk 2 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/is_2.parquet
# Saved is chunk 3 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/is_3.parquet
# Saved is chunk 4 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/is_4.parquet
# Saved it chunk 0 with 61 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/it_0.parquet
# Saved it chunk 1 with 61 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/it_1.parquet
# Saved it chunk 2 with 61 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/it_2.parquet
# Saved it chunk 3 with 61 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/it_3.parquet
# Saved it chunk 4 with 58 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/it_4.parquet
# Saved ja chunk 0 with 139 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ja_0.parquet
# Saved ja chunk 1 with 139 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ja_1.parquet
# Saved ja chunk 2 with 139 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ja_2.parquet
# Saved ja chunk 3 with 139 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ja_3.parquet
# Saved ja chunk 4 with 137 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ja_4.parquet
# Saved jv chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/jv_0.parquet
# Saved jv chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/jv_1.parquet
# Saved jv chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/jv_2.parquet
# Saved jv chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/jv_3.parquet
# Saved jv chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/jv_4.parquet
# Saved ka chunk 0 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ka_0.parquet
# Saved ka chunk 1 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ka_1.parquet
# Saved ka chunk 2 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ka_2.parquet
# Saved ka chunk 3 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ka_3.parquet
# Saved ka chunk 4 with 15 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ka_4.parquet
# Saved kk chunk 0 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kk_0.parquet
# Saved kk chunk 1 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kk_1.parquet
# Saved kk chunk 2 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kk_2.parquet
# Saved kk chunk 3 with 13 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kk_3.parquet
# Saved kk chunk 4 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kk_4.parquet
# Saved km chunk 0 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/km_0.parquet
# Saved km chunk 1 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/km_1.parquet
# Saved km chunk 2 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/km_2.parquet
# Saved km chunk 3 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/km_3.parquet
# Saved km chunk 4 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/km_4.parquet
# Saved kn chunk 0 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kn_0.parquet
# Saved kn chunk 1 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kn_1.parquet
# Saved kn chunk 2 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kn_2.parquet
# Saved kn chunk 3 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kn_3.parquet
# Saved kn chunk 4 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/kn_4.parquet
# Saved ko chunk 0 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ko_0.parquet
# Saved ko chunk 1 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ko_1.parquet
# Saved ko chunk 2 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ko_2.parquet
# Saved ko chunk 3 with 109 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ko_3.parquet
# Saved ko chunk 4 with 106 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ko_4.parquet
# Saved ku chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ku_0.parquet
# Saved ku chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ku_1.parquet
# Saved ku chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ku_2.parquet
# Saved ku chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ku_3.parquet
# Saved ku chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ku_4.parquet
# Saved ky chunk 0 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ky_0.parquet
# Saved ky chunk 1 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ky_1.parquet
# Saved ky chunk 2 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ky_2.parquet
# Saved ky chunk 3 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ky_3.parquet
# Saved ky chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ky_4.parquet
# Saved la chunk 0 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/la_0.parquet
# Saved la chunk 1 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/la_1.parquet
# Saved la chunk 2 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/la_2.parquet
# Saved la chunk 3 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/la_3.parquet
# Saved la chunk 4 with 5 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/la_4.parquet
# Saved lo chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lo_0.parquet
# Saved lo chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lo_1.parquet
# Saved lo chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lo_2.parquet
# Saved lo chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lo_3.parquet
# Saved lo chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lo_4.parquet
# Saved lt chunk 0 with 28 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lt_0.parquet
# Saved lt chunk 1 with 28 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lt_1.parquet
# Saved lt chunk 2 with 28 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lt_2.parquet
# Saved lt chunk 3 with 28 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lt_3.parquet
# Saved lt chunk 4 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lt_4.parquet
# Saved lv chunk 0 with 18 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lv_0.parquet
# Saved lv chunk 1 with 18 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lv_1.parquet
# Saved lv chunk 2 with 18 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lv_2.parquet
# Saved lv chunk 3 with 18 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lv_3.parquet
# Saved lv chunk 4 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/lv_4.parquet
# Saved mg chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mg_0.parquet
# Saved mg chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mg_1.parquet
# Saved mg chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mg_2.parquet
# Saved mg chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mg_3.parquet
# Saved mg chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mg_4.parquet
# Saved mk chunk 0 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mk_0.parquet
# Saved mk chunk 1 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mk_1.parquet
# Saved mk chunk 2 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mk_2.parquet
# Saved mk chunk 3 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mk_3.parquet
# Saved mk chunk 4 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mk_4.parquet
# Saved ml chunk 0 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ml_0.parquet
# Saved ml chunk 1 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ml_1.parquet
# Saved ml chunk 2 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ml_2.parquet
# Saved ml chunk 3 with 16 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ml_3.parquet
# Saved ml chunk 4 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ml_4.parquet
# Saved mn chunk 0 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mn_0.parquet
# Saved mn chunk 1 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mn_1.parquet
# Saved mn chunk 2 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mn_2.parquet
# Saved mn chunk 3 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mn_3.parquet
# Saved mn chunk 4 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mn_4.parquet
# Saved mr chunk 0 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mr_0.parquet
# Saved mr chunk 1 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mr_1.parquet
# Saved mr chunk 2 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mr_2.parquet
# Saved mr chunk 3 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mr_3.parquet
# Saved mr chunk 4 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/mr_4.parquet
# Saved ms chunk 0 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ms_0.parquet
# Saved ms chunk 1 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ms_1.parquet
# Saved ms chunk 2 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ms_2.parquet
# Saved ms chunk 3 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ms_3.parquet
# Saved ms chunk 4 with 17 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ms_4.parquet
# Saved my chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_0.parquet
# Saved my chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_1.parquet
# Saved my chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_2.parquet
# Saved my chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_3.parquet
# Saved my chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_4.parquet
# Saved my_zaw chunk 0 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_zaw_0.parquet
# Saved my_zaw chunk 1 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_zaw_1.parquet
# Saved my_zaw chunk 2 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_zaw_2.parquet
# Saved my_zaw chunk 3 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_zaw_3.parquet
# Saved my_zaw chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/my_zaw_4.parquet
# Saved ne chunk 0 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ne_0.parquet
# Saved ne chunk 1 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ne_1.parquet
# Saved ne chunk 2 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ne_2.parquet
# Saved ne chunk 3 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ne_3.parquet
# Saved ne chunk 4 with 6 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ne_4.parquet
# Saved nl chunk 0 with 59 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/nl_0.parquet
# Saved nl chunk 1 with 59 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/nl_1.parquet
# Saved nl chunk 2 with 59 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/nl_2.parquet
# Saved nl chunk 3 with 59 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/nl_3.parquet
# Saved nl chunk 4 with 57 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/nl_4.parquet
# Saved no chunk 0 with 98 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/no_0.parquet
# Saved no chunk 1 with 98 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/no_1.parquet
# Saved no chunk 2 with 98 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/no_2.parquet
# Saved no chunk 3 with 98 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/no_3.parquet
# Saved no chunk 4 with 98 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/no_4.parquet
# Saved om chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/om_0.parquet
# Saved om chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/om_1.parquet
# Saved om chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/om_2.parquet
# Saved om chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/om_3.parquet
# Saved om chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/om_4.parquet
# Saved or chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/or_0.parquet
# Saved or chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/or_1.parquet
# Saved or chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/or_2.parquet
# Saved or chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/or_3.parquet
# Saved or chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/or_4.parquet
# Saved pa chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pa_0.parquet
# Saved pa chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pa_1.parquet
# Saved pa chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pa_2.parquet
# Saved pa chunk 3 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pa_3.parquet
# Saved pa chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pa_4.parquet
# Saved pl chunk 0 with 90 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pl_0.parquet
# Saved pl chunk 1 with 90 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pl_1.parquet
# Saved pl chunk 2 with 90 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pl_2.parquet
# Saved pl chunk 3 with 90 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pl_3.parquet
# Saved pl chunk 4 with 86 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pl_4.parquet
# Saved ps chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ps_0.parquet
# Saved ps chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ps_1.parquet
# Saved ps chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ps_2.parquet
# Saved ps chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ps_3.parquet
# Saved ps chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ps_4.parquet
# Saved pt chunk 0 with 99 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pt_0.parquet
# Saved pt chunk 1 with 99 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pt_1.parquet
# Saved pt chunk 2 with 99 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pt_2.parquet
# Saved pt chunk 3 with 99 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pt_3.parquet
# Saved pt chunk 4 with 95 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/pt_4.parquet
# Saved ro chunk 0 with 123 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ro_0.parquet
# Saved ro chunk 1 with 123 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ro_1.parquet
# Saved ro chunk 2 with 123 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ro_2.parquet
# Saved ro chunk 3 with 123 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ro_3.parquet
# Saved ro chunk 4 with 122 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ro_4.parquet
# Saved ru chunk 0 with 556 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ru_0.parquet
# Saved ru chunk 1 with 556 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ru_1.parquet
# Saved ru chunk 2 with 556 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ru_2.parquet
# Saved ru chunk 3 with 556 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ru_3.parquet
# Saved ru chunk 4 with 556 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ru_4.parquet
# Saved sa chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sa_0.parquet
# Saved sa chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sa_1.parquet
# Saved sa chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sa_2.parquet
# Saved sa chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sa_3.parquet
# Saved sa chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sa_4.parquet
# Saved sd chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sd_0.parquet
# Saved sd chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sd_1.parquet
# Saved sd chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sd_2.parquet
# Saved sd chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sd_3.parquet
# Saved sd chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sd_4.parquet
# Saved si chunk 0 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/si_0.parquet
# Saved si chunk 1 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/si_1.parquet
# Saved si chunk 2 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/si_2.parquet
# Saved si chunk 3 with 8 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/si_3.parquet
# Saved si chunk 4 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/si_4.parquet
# Saved sk chunk 0 with 47 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sk_0.parquet
# Saved sk chunk 1 with 47 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sk_1.parquet
# Saved sk chunk 2 with 47 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sk_2.parquet
# Saved sk chunk 3 with 47 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sk_3.parquet
# Saved sk chunk 4 with 44 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sk_4.parquet
# Saved sl chunk 0 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sl_0.parquet
# Saved sl chunk 1 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sl_1.parquet
# Saved sl chunk 2 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sl_2.parquet
# Saved sl chunk 3 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sl_3.parquet
# Saved sl chunk 4 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sl_4.parquet
# Saved so chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/so_0.parquet
# Saved so chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/so_1.parquet
# Saved so chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/so_2.parquet
# Saved so chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/so_3.parquet
# Saved so chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/so_4.parquet
# Saved sq chunk 0 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sq_0.parquet
# Saved sq chunk 1 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sq_1.parquet
# Saved sq chunk 2 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sq_2.parquet
# Saved sq chunk 3 with 11 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sq_3.parquet
# Saved sq chunk 4 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sq_4.parquet
# Saved sr chunk 0 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sr_0.parquet
# Saved sr chunk 1 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sr_1.parquet
# Saved sr chunk 2 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sr_2.parquet
# Saved sr chunk 3 with 19 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sr_3.parquet
# Saved sr chunk 4 with 15 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sr_4.parquet
# Saved su chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/su_0.parquet
# Saved su chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/su_1.parquet
# Saved su chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/su_2.parquet
# Saved su chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/su_3.parquet
# Saved su chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/su_4.parquet
# Saved sv chunk 0 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sv_0.parquet
# Saved sv chunk 1 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sv_1.parquet
# Saved sv chunk 2 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sv_2.parquet
# Saved sv chunk 3 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sv_3.parquet
# Saved sv chunk 4 with 21 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sv_4.parquet
# Saved sw chunk 0 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sw_0.parquet
# Saved sw chunk 1 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sw_1.parquet
# Saved sw chunk 2 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sw_2.parquet
# Saved sw chunk 3 with 4 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sw_3.parquet
# Saved sw chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/sw_4.parquet
# Saved ta chunk 0 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_0.parquet
# Saved ta chunk 1 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_1.parquet
# Saved ta chunk 2 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_2.parquet
# Saved ta chunk 3 with 25 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_3.parquet
# Saved ta chunk 4 with 22 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_4.parquet
# Saved ta_rom chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_rom_0.parquet
# Saved ta_rom chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_rom_1.parquet
# Saved ta_rom chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_rom_2.parquet
# Saved ta_rom chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_rom_3.parquet
# Saved ta_rom chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ta_rom_4.parquet
# Saved te chunk 0 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_0.parquet
# Saved te chunk 1 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_1.parquet
# Saved te chunk 2 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_2.parquet
# Saved te chunk 3 with 10 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_3.parquet
# Saved te chunk 4 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_4.parquet
# Saved te_rom chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_rom_0.parquet
# Saved te_rom chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_rom_1.parquet
# Saved te_rom chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_rom_2.parquet
# Saved te_rom chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_rom_3.parquet
# Saved te_rom chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/te_rom_4.parquet
# Saved th chunk 0 with 144 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/th_0.parquet
# Saved th chunk 1 with 144 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/th_1.parquet
# Saved th chunk 2 with 144 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/th_2.parquet
# Saved th chunk 3 with 144 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/th_3.parquet
# Saved th chunk 4 with 141 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/th_4.parquet
# Saved tl chunk 0 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tl_0.parquet
# Saved tl chunk 1 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tl_1.parquet
# Saved tl chunk 2 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tl_2.parquet
# Saved tl chunk 3 with 7 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tl_3.parquet
# Saved tl chunk 4 with 3 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tl_4.parquet
# Saved tr chunk 0 with 42 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tr_0.parquet
# Saved tr chunk 1 with 42 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tr_1.parquet
# Saved tr chunk 2 with 42 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tr_2.parquet
# Saved tr chunk 3 with 42 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tr_3.parquet
# Saved tr chunk 4 with 41 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/tr_4.parquet
# Saved ug chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ug_0.parquet
# Saved ug chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ug_1.parquet
# Saved ug chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ug_2.parquet
# Saved ug chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ug_3.parquet
# Saved ug chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ug_4.parquet
# Saved uk chunk 0 with 170 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uk_0.parquet
# Saved uk chunk 1 with 170 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uk_1.parquet
# Saved uk chunk 2 with 170 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uk_2.parquet
# Saved uk chunk 3 with 170 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uk_3.parquet
# Saved uk chunk 4 with 166 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uk_4.parquet
# Saved ur chunk 0 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_0.parquet
# Saved ur chunk 1 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_1.parquet
# Saved ur chunk 2 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_2.parquet
# Saved ur chunk 3 with 12 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_3.parquet
# Saved ur chunk 4 with 9 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_4.parquet
# Saved ur_rom chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_rom_0.parquet
# Saved ur_rom chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_rom_1.parquet
# Saved ur_rom chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_rom_2.parquet
# Saved ur_rom chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_rom_3.parquet
# Saved ur_rom chunk 4 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/ur_rom_4.parquet
# Saved uz chunk 0 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uz_0.parquet
# Saved uz chunk 1 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uz_1.parquet
# Saved uz chunk 2 with 2 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uz_2.parquet
# Saved uz chunk 3 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uz_3.parquet
# Saved uz chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/uz_4.parquet
# Saved vi chunk 0 with 275 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/vi_0.parquet
# Saved vi chunk 1 with 275 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/vi_1.parquet
# Saved vi chunk 2 with 275 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/vi_2.parquet
# Saved vi chunk 3 with 275 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/vi_3.parquet
# Saved vi chunk 4 with 273 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/vi_4.parquet
# Saved xh chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/xh_0.parquet
# Saved xh chunk 1 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/xh_1.parquet
# Saved xh chunk 2 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/xh_2.parquet
# Saved xh chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/xh_3.parquet
# Saved xh chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/xh_4.parquet
# Saved yi chunk 0 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/yi_0.parquet
# Saved yi chunk 1 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/yi_1.parquet
# Saved yi chunk 2 with 1 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/yi_2.parquet
# Saved yi chunk 3 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/yi_3.parquet
# Saved yi chunk 4 with 0 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/yi_4.parquet
# Saved zh-Hans chunk 0 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hans_0.parquet
# Saved zh-Hans chunk 1 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hans_1.parquet
# Saved zh-Hans chunk 2 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hans_2.parquet
# Saved zh-Hans chunk 3 with 94 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hans_3.parquet
# Saved zh-Hans chunk 4 with 93 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hans_4.parquet
# Saved zh-Hant chunk 0 with 34 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hant_0.parquet
# Saved zh-Hant chunk 1 with 34 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hant_1.parquet
# Saved zh-Hant chunk 2 with 34 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hant_2.parquet
# Saved zh-Hant chunk 3 with 34 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hant_3.parquet
# Saved zh-Hant chunk 4 with 30 rows to /content/drive/MyDrive/KD-EE-XLMR/minimal_data/distillation_data_split/zh-Hant_4.parquet
